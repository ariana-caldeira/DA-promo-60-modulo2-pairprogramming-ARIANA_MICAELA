# %% [markdown]
# ## LECTURA DE FICHEROS

# %% [markdown]
# #### PAIR PROGRAMMING

# %% [markdown]
# 1 - Hacer las importaciones necesarias para abrir un archivo de tipo csv en Pandas.

# %%
import json

# %%
import pandas as pd

# %%
#porque no funcionó el relative path ?
df_videogames = pd.read_csv("/Users/arii/Desktop/ADALAB/Ejercicios/modulo_2/DA-promo-60-modulo2-pairprogramming-ARIANA_MICAELA/FILES/videogames.csv")

# %% [markdown]
# 2 - Abrir el archivo, creando un dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

# %%
df_videogames.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
df_videogames = pd.read_csv("/Users/arii/Desktop/ADALAB/Ejercicios/modulo_2/DA-promo-60-modulo2-pairprogramming-ARIANA_MICAELA/FILES/videogames.csv", index_col = 0)

# %%
df_videogames.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %% [markdown]
# 3 - Guardar el dataframe en formato Excel y después crear un dataframe con el Excel. ¿El dataframe es similar al que teníais antes?

# %%
df_videogames.to_excel("/Users/arii/Desktop/ADALAB/Ejercicios/modulo_2/DA-promo-60-modulo2-pairprogramming-ARIANA_MICAELA/FILES/videogames.xlsx")

# %% [markdown]
# 4 - Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv .

# %%
df_videogames.to_csv("/Users/arii/Desktop/ADALAB/Ejercicios/modulo_2/DA-promo-60-modulo2-pairprogramming-ARIANA_MICAELA/FILES/videogames_2.csv")

# %% [markdown]
# 5 - Copia el archivo personal.json en la carpeta Files.

# %% [markdown]
# 6 - Abre el fichero json (con el json.load(f)) y haz las modificaciones necesarias para que tenga formato de tabla (Para esto necesitas normalizar los datos con el pd.json_normalize).

# %%
with open("FILES/personal_1.json", "r") as file:
    personal = json.load(file)

# %%
personal = personal['workers']

# %%
# preguntar a Cesar sobre este 'normalize'
df_personal = pd.json_normalize(personal)
display(df_personal)
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN

# %% [markdown]
# 7 - Guardar el json modificado y abrirlo en Pandas.¿Cómo queda ahora?

# %%
with open("/Users/arii/Desktop/ADALAB/Ejercicios/modulo_2/DA-promo-60-modulo2-pairprogramming-ARIANA_MICAELA/FILES/personal_2.json", "w") as file:
    json.dump(personal, file)

# %%
df_personal = pd.read_json("/Users/arii/Desktop/ADALAB/Ejercicios/modulo_2/DA-promo-60-modulo2-pairprogramming-ARIANA_MICAELA/FILES/personal_2.json")

# %%
df_personal.head()
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
